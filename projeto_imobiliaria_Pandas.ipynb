# %% [markdown]
# <a href="https://colab.research.google.com/github/felipesayegg/Python-para-Data-Science/blob/main/projeto_imobiliaria_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Conhecendo a base de dados

# %% [markdown]
# ### Importar os dados

# %%
import pandas as pd # chamando a biblioteca e com isso tenho uma caixa de ferramenta para trbalahar com meus dados que são as funçoes que essa biblioteca tem

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
# importando a base de dados, temos essa url no nosso trelo, na parte informaçoes do projeto

# %%
dados = pd.read_csv(url)  # nesse dados esta separado por ; por isso não leu muito bem o arquivo

# %%
dados
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
dados = pd.read_csv(url, sep=';')  # aqui nesse argumento eu estou avisando que os dados não estao sendo separados por , e sim ;
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
dados.head(10)  #  aqui eu consigo visualiar as 10 primeiras
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
dados.tail(10) # as 10 ultimas
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 32950              Apartamento                Tijuca        1      0       0
# 32951              Apartamento        Vila Valqueire        2      0       0
# 32952       Casa de Condomínio       Barra da Tijuca        5      3       4
# 32953              Apartamento                 Méier        2      0       0
# 32954              Box/Garagem                Centro        0      0       0
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area    Valor  Condominio    IPTU
# 32950    28   1000.0       360.0    25.0
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #### O Pandas fornece diversas funções para importar e exportar dados em diferentes formatos. As principais funções do Pandas para importar dados são as seguintes:
#
#  read_csv(): Essa função é usada para ler arquivos CSV (Comma Separated Values), que são arquivos de texto que contêm dados separados por vírgulas. É possível passar diversos parâmetros para personalizar a leitura do csv, como delimitador, cabeçalho, tipo de encoding, entre outros.
#
#  read_excel(): Essa função é usada para ler arquivos do Excel (.xls ou .xlsx) e criar um DataFrame a partir dos dados.
#
# read_json(): Essa função é usada para ler arquivos JSON (JavaScript Object Notation), que são arquivos de texto que contêm dados em formato de objeto JavaScript.
#
# read_html(): Essa função é usada para ler tabelas HTML, que são estruturas de dados organizadas em formato de tabela em uma página da web.
#
#  read_sql(): Essa função é usada para ler dados de um banco de dados relacional, como o MySQL, PostgreSQL e SQL Server. O Pandas é capaz de importar dados de diferentes formas, permitindo ajustar parâmetros como a consulta, o nome da tabela e o tipo de dados das colunas.

# %% [markdown]
# ### Caracteristicas gerais da base de dados

# %%
dados.shape   # quantidades de linha e colkunas do nosos dataframe
# Out:
# (32960, 9)

# %%
dados.columns # nomes das colunas
# Out:
# Index(['Tipo', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
dados.info() # informações sobre o dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32960 entries, 0 to 32959
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        32960 non-null  object
#  1   Bairro      32960 non-null  object
#  2   Quartos     32960 non-null  int64
#  3   Vagas       32960 non-null  int64
#  4   Suites      32960 non-null  int64
#  5   Area        32960 non-null  int64
#  6   Valor       32943 non-null  float64
#  7   Condominio  28867 non-null  float64
#  8   IPTU        22723 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 2.3+ MB

# %%
dados["Tipo"]  # dados do tipo string/ objetct
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
dados[['Quartos', 'Valor']] # dados do tipo numerico, int dados inteirios , float decimal
# Out:
#        Quartos   Valor
# 0            1  1700.0
# 1            2  7000.0
# 2            0  5200.0
# 3            1   800.0
# 4            1   800.0
# ...        ...     ...
# 32955        0   800.0
# 32956        3  1800.0
# 32957        2  1400.0
# 32958        2  3000.0
# 32959        0  6500.0
#
# [32960 rows x 2 columns]

# %% [markdown]
# Para praticar os métodos aprendidos no decorrer dessa aula e também aprender novos, vamos realizar algumas análises utilizando um arquivo csv diferente: alunos.csv.
#
# 1) Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.
#
# 2) Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.
#
# 3) Confira a quantidade de linhas e colunas desse DataFrame.
#
# 4) Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.
#
# Extra: Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc). Dica: pesquise pelo método describe.

# %%
url_alunos = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv"

# %%
dados_alunos = pd.read_csv(url_alunos) # dados ja tinha sido separados por , então não precisou do sep

dados_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
dados_alunos.head(7) # metodo head as 10 primeiras eu colocando 7 como parametro vai vim 7
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
dados_alunos.tail(5) # as 5 ultimas
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %%
dados_alunos.shape # tem 18 linhas e 4 colunas
# Out:
# (18, 4)

# %%
# visualizando os nomes das colunas
dados_alunos.columns
# Out:
# Index(['Nome', 'Idade', 'Notas', 'Aprovado'], dtype='object')

# %%
dados_alunos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes

# %%
# selecionando uma coluna
dados_alunos['Nome']
# Out:
# 0           Ary
# 1           Ana
# 2         Cátia
# 3         Denis
# 4          Beto
# 5         Bruna
# 6          Dara
# 7        Carlos
# 8         Alice
# 9         Vitor
# 10       Daniel
# 11         Igor
# 12    Sthefanie
# 13        Mirla
# 14        Paulo
# 15       Mylena
# 16        Lucas
# 17        Nadia
# Name: Nome, dtype: object

# %%
#selecionando múltiplas colunas
dados_alunos[['Idade', 'Notas']]
# Out:
#     Idade  Notas
# 0      20    7.5
# 1      18    NaN
# 2      27    2.5
# 3      18    5.0
# 4      21   10.0
# 5      23    NaN
# 6      21    7.0
# 7      19    6.0
# 8      35    5.6
# 9      28    NaN
# 10     21    NaN
# 11     24    4.5
# 12     26    9.5
# 13     25    9.0
# 14     37    NaN
# 15     29    7.0
# 16     33    NaN
# 17     34    8.0

# %%
# conferindo os tipos de dados de cada coluna
dados_alunos.dtypes
# Out:
# Nome         object
# Idade         int64
# Notas       float64
# Aprovado       bool
# dtype: object

# %%
dados_alunos.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# # Analise exploratoria de dados

# %% [markdown]
# ### Qual o valor medio de aluguel por tipo de imovel ?

# %%
dados.head() # vamos observar quais colunas vão ser interressante para calcular o valor do imovel
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor'].mean() # valor medio do aluguel
# Out:
# 12952.659715265761

# %%
dados.groupby('Tipo').mean(numeric_only=True) # valor medio por tipo de imovel
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %%
dados.groupby('Tipo')['Valor'].mean() # dessa fomra a gente ja seleciona uma lista numera do dataframe então ele vai puxar so ela não todas igual em cima
# Out:
# Tipo
# Apartamento                      4744.614648
# Box/Garagem                      1899.756098
# Casa                             6793.454922
# Casa Comercial                  14478.264151
# Casa de Condomínio              11952.061245
# Casa de Vila                     1574.369478
# Chácara                          4900.000000
# Conjunto Comercial/Sala         14715.045521
# Flat                             4546.189076
# Galpão/Depósito/Armazém         53407.062600
# Hotel                           25000.000000
# Indústria                      120000.000000
# Loft                             2557.882353
# Loja Shopping/ Ct Comercial      8126.178862
# Loja/Salão                      13769.646770
# Loteamento/Condomínio           22000.000000
# Pousada/Chalé                    1480.000000
# Prédio Inteiro                 498637.239203
# Quitinete                        1246.840909
# Studio                           2400.000000
# Sítio                           12499.000000
# ...

# %%
dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor') # pegando os tipos e dando as medias e trazendo em ordem do menor para maior
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
df_preço_tipo = dados.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_preço_tipo.plot(kind='bar', figsize=(14,10), color='blue') # chamando datframe e usando plot para plotar grafico de barras e o tamnho e a cor
# Out:
# <Axes: xlabel='Tipo'>

# %% [markdown]
# Dados que estamos preparando esse dataset para previsão e as medias estão muito difrentes e a empresa so vai trabalhar com residencial precisamos tirar os lugares comerciais

# %% [markdown]
# O método groupby do Pandas permite agrupar e resumir dados de um DataFrame, com base em um ou mais critérios. Esses critérios podem ser variáveis numéricas ou categóricas, como colunas ou índices do DataFrame.
#
# A ideia por trás do groupby é dividir os dados em grupos com base nos critérios selecionados e, em seguida, aplicar uma operação a esses grupos. Essa operação pode ser uma função de agregação, como soma, média, contagem, desvio padrão, entre outras, ou mesmo uma operação personalizada definida pela pessoa usuária.
#
# Esse método possui diversos parâmetros, alguns deles são:
#
# by: esse é o parâmetro mais comum e é usado para especificar a coluna ou colunas que queremos agrupar. Como argumento dele, podemos passar o nome de uma coluna ou uma lista de nomes de colunas;
#
# axis: utilizamos esse parâmetro para especificar o eixo ao longo do qual queremos agrupar. O valor padrão dele é 0, o que significa que as linhas serão agrupadas. Se quisermos agrupar as colunas, devemos definir esse parâmetro como 1;
#
# sort: esse parâmetro é um booleano (True ou False) que indica se os grupos devem ser ordenados pelo valor da coluna de agrupamento. O valor padrão é True;
#
# dropna: utilizamos esse parâmetro para controlar se os valores ausentes (NaN) serão excluídos ou não durante o processo de agrupamento. O valor padrão é True.

# %% [markdown]
# Vamos analisar um exemplo simples utilizando o groupby. Suponha que temos o seguinte DataFrame:
# ---
#
#
#
# ---

# %%
df = pd.DataFrame({
   'Animal': ['Cachorro', 'Gato', 'Elefante', 'Cachorro', 'Gato', 'Elefante'],
   'Cor': ['Preto', 'Branco', 'Cinza', 'Marrom', 'Preto', 'Marrom'],
   'Quantidade': [2, 3, 1, 4, 2, 2]
})
df
# Out:
#      Animal     Cor  Quantidade
# 0  Cachorro   Preto           2
# 1      Gato  Branco           3
# 2  Elefante   Cinza           1
# 3  Cachorro  Marrom           4
# 4      Gato   Preto           2
# 5  Elefante  Marrom           2

# %%
df.groupby('Animal').sum(numeric_only=True) # Selecinou animal então printar os animais que tem no dataframe e depois fazer a soma
# Out:
#           Quantidade
# Animal
# Cachorro           6
# Elefante           3
# Gato               5

# %%
df.groupby(['Animal', 'Cor'])[['Quantidade']].sum() #  Podemos também usar o método groupby para agrupar os dados por múltiplas colunas. Por exemplo, vamos agrupar pelo tipo do animal e também pela cor e realizar a soma da coluna "Quantidade":
# Out:
#                  Quantidade
# Animal   Cor
# Cachorro Marrom           4
#          Preto            2
# Elefante Cinza            1
#          Marrom           2
# Gato     Branco           3
#          Preto            2

# %% [markdown]
# #Removendo os Imóveis comerciais

# %%
dados.Tipo.unique() # visualizando os tipos de imovel
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']
               # lista com imoveis que queremos remover

# %%
dados.query('@imoveis_comerciais in Tipo')# imagina que o comando query ele tem acesso as linhas do meu dataFrame e passa uma por 1 conseguindo selecionalas via argumento
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
df = dados.query('@imoveis_comerciais not in Tipo')# usei o not na query assim ele tira os imoveis selecionados na lista

# %%
df.Tipo.unique() # visualizando os tipos de imovel
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
df_preço_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
df_preço_tipo.plot(kind='bar', figsize=(14,10), color='blue') # chamando datframe e usando plot para plotar grafico de barras e o tamnho e a cor
# Out:
# <Axes: xlabel='Tipo'>

# %% [markdown]
# Qual o perctual de cada Tipo de imovel na nossa base de dados ?

# %%
df.Tipo.value_counts(normalize= True) # conta a quantidade de cada tipo de imovel
# Out:
# Tipo
# Apartamento           0.845139
# Casa de Condomínio    0.043096
# Casa                  0.041842
# Quitinete             0.036173
# Flat                  0.020596
# Casa de Vila          0.010774
# Loft                  0.002207
# Studio                0.000173
# Name: proportion, dtype: float64

# %%
df.Tipo.value_counts(normalize= True).to_frame().sort_values('Tipo')  # conta a quantidade de cada tipo de imovel
# Out:
#                     proportion
# Tipo
# Apartamento           0.845139
# Casa                  0.041842
# Casa de Condomínio    0.043096
# Casa de Vila          0.010774
# Flat                  0.020596
# Loft                  0.002207
# Quitinete             0.036173
# Studio                0.000173

# %%
df_percentual_tipo = df.Tipo.value_counts(normalize= True).to_frame().sort_values('Tipo')
df_percentual_tipo.plot(kind='bar', figsize=(14,10), color='blue', xlabel='Tipo', ylabel='Percentual')
# plotar o grafico para ver o percentual
# Out:
# <Axes: xlabel='Tipo', ylabel='Percentual'>

# %% [markdown]
# Analisando o gráfico, podemos notar que os imóveis do tipo apartamento representam a maioria da nossa base de dados: mais de 80% dos dados

# %% [markdown]
# # Selecionando apenas os imoveis do tipo apartamento

# %%
df.query('Tipo == "Apartamento"')  # Entrou na linhas eu selecionou as que eram tipo apartamento
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   NaN
# ...

# %%
df = df.query('Tipo == "Apartamento"')

# %%
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# 1 - Calcular a média de quartos por apartamento;

# %%
df.groupby('Tipo')[['Quartos']].mean().sort_values('Quartos')
# Out:
#               Quartos
# Tipo
# Apartamento  2.481569

# %%
df.Quartos.mean()
# Out:
# 2.481568707761622

# %%
df["Quartos"].mean()
# Out:
# 2.481568707761622

# %% [markdown]
# 2) Conferir quantos bairros únicos existem na nossa base de dados;

# %%
len(df.Bairro.unique())  # vai entrar dentro de bairro e achar o nome e anotar se repirit não vai anotar
# Out:
# 149

# %%
df['Bairro'].nunique()
# Além disso, também podemos utilizar um método do próprio Pandas que já faz a contagem de elementos únicos de uma coluna específica de forma direta. Esse método é o nunique():
# Out:
# 149

# %% [markdown]
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;

# %%
df.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False)
# Out:
#                                Valor
# Bairro
# Joá                     15500.000000
# Arpoador                12429.769231
# Cidade Jardim           12000.000000
# Ipanema                  9487.205317
# Botafogo                 9369.207116
# ...                              ...
# Inhoaíba                  650.000000
# Cosmos                    610.000000
# Santa Cruz                590.000000
# Paciência                 510.000000
# Ricardo de Albuquerque    340.000000
#
# [149 rows x 1 columns]

# %% [markdown]
# 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
df_bairro_valor = df.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False).head()
df_bairro_valor
# Out:
#                       Valor
# Bairro
# Joá            15500.000000
# Arpoador       12429.769231
# Cidade Jardim  12000.000000
# Ipanema         9487.205317
# Botafogo        9369.207116

# %%
df_bairro_valor.plot(kind='barh', figsize=(14,10), color='blue');

# %% [markdown]
# Nessa aula, você aprendeu a:
# Identificar o que fazer durante um processo de análise exploratória;
# Calcular a média de valores de um DataFrame;
# Agrupar os dados de acordo com uma coluna específica utilizando o groupby;
# Fazer seleções utilizando o método query;
# Transformar Series em DataFrames;
# Ordenar valores de um DataFrame com o sort_values;
# Plotar gráficos de barras verticais e horizontais;
# Visualizar valores únicos com o unique;
# Utilizar o value_counts para contar valores únicos e calcular percentuais;
# Mudar nomes de colunas.

# %% [markdown]
# # Tratando e filtrando os dados

# %% [markdown]
# ### Lidando com os dados nulos

# %%
df.isnull()  # metodo meio que vai avalaiar se é um dado nulo se for vai vim como true
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 3      False   False    False  False   False  False  False       False  False
# 4      False   False    False  False   False  False  False       False   True
# 5      False   False    False  False   False  False  False        True   True
# 6      False   False    False  False   False  False  False       False  False
# 10     False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 32951  False   False    False  False   False  False  False       False   True
# 32953  False   False    False  False   False  False  False       False  False
# 32956  False   False    False  False   False  False  False       False  False
# 32957  False   False    False  False   False  False  False       False  False
# 32958  False   False    False  False   False  False  False       False   True
#
# [19532 rows x 9 columns]

# %%
df.isnull().sum() # consigo ver em quais coluans tenho dados nulos como vc pode ver valor condominio e iptu tem
  # metodo meio que vai avalaiar se é um dado nulo se for vai vim como true
# Out:
# Tipo             0
# Bairro           0
# Quartos          0
# Vagas            0
# Suites           0
# Area             0
# Valor            7
# Condominio     745
# IPTU          5472
# dtype: int64

# %%
df.fillna(0)
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# 6      Apartamento              Cachambi        2      0       0    50
# 10     Apartamento                Centro        1      0       0    36
# ...            ...                   ...      ...    ...     ...   ...
# 32951  Apartamento        Vila Valqueire        2      0       0    52
# 32953  Apartamento                 Méier        2      0       0    70
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 3       800.0       390.0  20.0
# 4       800.0       230.0   0.0
# ...

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Tipo          0
# Bairro        0
# Quartos       0
# Vagas         0
# Suites        0
# Area          0
# Valor         0
# Condominio    0
# IPTU          0
# dtype: int64

# %% [markdown]
# Removendo registros

# %%
df.query("Valor == 0 | Condominio == 0") # com esse comando vai linha por linha buscando as linhas q o o valor e condomino esta = a 0
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 5      Apartamento     Vista Alegre        3      1       0    70  1200.0
# 10     Apartamento           Centro        1      0       0    36  1200.0
# 76     Apartamento  Barra da Tijuca        2      1       1    70     0.0
# 113    Apartamento       Praça Seca        2      0       0    80  1000.0
# 166    Apartamento    Rocha Miranda        2      1       0    50  1100.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 32609  Apartamento       Copacabana        3      0       0   130  4600.0
# 32643  Apartamento        Guadalupe        1      0       0    40   550.0
# 32666  Apartamento       Bonsucesso        1      0       0    60  1000.0
# 32708  Apartamento         Flamengo        2      0       0    59  3500.0
# 32809  Apartamento        Cascadura        3      0       1    70  1200.0
#
#        Condominio  IPTU
# 5             0.0   0.0
# 10            0.0   0.0
# ...

# %%
df.query("Valor == 0 | Condominio == 0").index # com esse comando vai linha por linha buscando as linhas q o o valor e condomino esta = a 0
# Out:
# Index([    5,    10,    76,   113,   166,   194,   258,   265,   275,   292,
#        ...
#        32420, 32438, 32480, 32538, 32584, 32609, 32643, 32666, 32708, 32809],
#       dtype='int64', length=752)

# %%
registros_a_remover = df.query('Valor == 0 | Condominio == 0').index

# %%
df.drop(registros_a_remover, axis=0, inplace=True) # primiero argumento de drop com uma lista com os indices que queremos remover que foi puxado anteriormente
# axis vai dizer se é linha ou coluna que vamos remover quando é 0 e linha
# inplace = True essas defição vai realmente mudar meu data frame

# %%
df.query("Valor == 0 | Condominio == 0") # Veio um data frame vazio pois não tem mais nenhuma linha que precisamos remover ja tirou
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %%
df.head()  # analisar se precisa remover mas alguma cisa do banco de dados
# Out:
#            Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento               Centro        1      0       0    15   800.0
# 4   Apartamento         Higienópolis        1      0       0    48   800.0
# 6   Apartamento             Cachambi        2      0       0    50  1300.0
# 11  Apartamento               Grajaú        2      1       0    70  1500.0
# 12  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   0.0
# 6        301.0  17.0
# 11       642.0  74.0
# 12       455.0  14.0

# %%
df.Tipo.unique()
# Out:
# array(['Apartamento'], dtype=object)

# %%
df.drop("Tipo", axis=1, inplace=True) # remover uma coluna

# %%
df.head()
# Out:
#                  Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3                Centro        1      0       0    15   800.0       390.0
# 4          Higienópolis        1      0       0    48   800.0       230.0
# 6              Cachambi        2      0       0    50  1300.0       301.0
# 11               Grajaú        2      1       0    70  1500.0       642.0
# 12  Lins de Vasconcelos        3      1       1    90  1500.0       455.0
#
#     IPTU
# 3   20.0
# 4    0.0
# 6   17.0
# 11  74.0
# 12  14.0

# %% [markdown]
# # Filtros

# %% [markdown]
# ## 1. Apartamento que possuem 1 quarto e alguem menor que 1200

# %%
df["Quartos"] == 1 # voltar uma series mostrando false par qual não é igual igual a 1 e true para as que são
# Out:
# 3         True
# 4         True
# 6        False
# 11       False
# 12       False
#          ...
# 32951    False
# 32953    False
# 32956    False
# 32957    False
# 32958    False
# Name: Quartos, Length: 18780, dtype: bool

# %%
selecao1 = df["Quartos"] == 1  # esta salvando dentro de uma variavel o filtro de ir em quartos e pagar os que forem 1
df[selecao1] # chamdno
# Out:
#                 Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 3               Centro        1      0       0    15   800.0       390.0
# 4         Higienópolis        1      0       0    48   800.0       230.0
# 13          Copacabana        1      0       1    40  2000.0       561.0
# 28              Tijuca        1      0       0    48   750.0       772.0
# 54              Centro        1      0       0    27   750.0       371.0
# ...                ...      ...    ...     ...   ...     ...         ...
# 32918          Ipanema        1      0       0    55  2000.0       630.0
# 32922  Barra da Tijuca        1      1       0    62  1700.0       945.0
# 32935           Leblon        1      1       1    50  4300.0      1730.0
# 32938       Copacabana        1      0       0    50  1950.0       450.0
# 32950           Tijuca        1      0       0    28  1000.0       360.0
#
#         IPTU
# 3       20.0
# 4        0.0
# 13      50.0
# 28      25.0
# 54      19.0
# ...

# %%
selecao2 = df["Valor"] < 1200
df[selecao2]
# Out:
#                         Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3                       Centro        1      0       0    15   800.0
# 4                 Higienópolis        1      0       0    48   800.0
# 19     Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 23                      Olaria        3      1       0    68  1000.0
# 28                      Tijuca        1      0       0    48   750.0
# ...                        ...      ...    ...     ...   ...     ...
# 32925                 Campinho        2      0       0    63   800.0
# 32930  Freguesia (Jacarepaguá)        2      1       0    60   500.0
# 32950                   Tijuca        1      0       0    28  1000.0
# 32951           Vila Valqueire        2      0       0    52  1000.0
# 32953                    Méier        2      0       0    70   900.0
#
#        Condominio   IPTU
# 3           390.0   20.0
# 4           230.0    0.0
# 19          300.0   28.0
# 23          670.0    0.0
# ...

# %%
selecao_final = selecao1 & selecao2 # esta colocnaod junto as duas qyers que vc colocou no data frame

df[selecao_final] # chamdno os datas frames com as querys
# Out:
#              Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio   IPTU
# 3            Centro        1      0       0    15   800.0       390.0   20.0
# 4      Higienópolis        1      0       0    48   800.0       230.0    0.0
# 28           Tijuca        1      0       0    48   750.0       772.0   25.0
# 54           Centro        1      0       0    27   750.0       371.0   19.0
# 94           Centro        1      1       0    37  1100.0       540.0  900.0
# ...             ...      ...    ...     ...   ...     ...         ...    ...
# 32596        Grajaú        1      0       1    37  1000.0       200.0    0.0
# 32617     Pechincha        1      0       1    69   900.0       640.0  126.0
# 32627        Glória        1      0       0    46  1100.0       453.0   32.0
# 32714      Botafogo        1      0       0    21  1000.0       282.0   25.0
# 32950        Tijuca        1      0       0    28  1000.0       360.0   25.0
#
# [499 rows x 8 columns]

# %%
df_1 = df[selecao_final]

# %% [markdown]
# 2 Apartamentos que possuem pelo menos 2 quartos, alguel menor que 3000 e area maior que 70

# %%
selecao = (df["Quartos"] >= 2) & (df["Valor"] < 3000) & (df["Area"] > 70) # aqui fiz as consultas todas juntas
df[selecao]
# Out:
#                          Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 12          Lins de Vasconcelos        3      1       1    90  1500.0
# 21                       Tijuca        2      1       0   110  1900.0
# 24                       Tijuca        2      1       0    78  2000.0
# 32                     Botafogo        2      1       0    76  2500.0
# 36     Recreio dos Bandeirantes        3      1       1   105  2300.0
# ...                         ...      ...    ...     ...   ...     ...
# 32934               Jacarepaguá        2      1       1    78  2200.0
# 32940           Barra da Tijuca        2      1       1    85  2250.0
# 32941           Barra da Tijuca        3      2       0    98  2300.0
# 32944  Recreio dos Bandeirantes        3      2       1    88  1550.0
# 32956               Jacarepaguá        3      1       2    78  1800.0
#
#        Condominio   IPTU
# 12          455.0   14.0
# 21          700.0  138.0
# 24          700.0    0.0
# ...

# %%
df_2 = df[selecao] # salvei a variavel das mudanças

# %% [markdown]
# Quais apartamentos possuem área maior que 80 m² ou aluguel menor que R$ 4.000,00?

# %%
selecao4 = (df["Area"]> 80) | (df["Valor"] < 4000) # operador or | voltar data frame com a area ou valor

# %% [markdown]
# # Salvando os dados

# %%
df.to_csv("dados_apartamentos.csv") # função muito importante para transfomrar os dados tratados em um csv

# %%
pd.read_csv("dados_apartamentos.csv") # ler o arquivo csv, mas como pode ver foi criados indix na hora de salvar então precisamos passar argumento pra iso não acontecer
# Out:
#        Unnamed: 0                Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0               3                Centro        1      0       0    15   800.0
# 1               4          Higienópolis        1      0       0    48   800.0
# 2               6              Cachambi        2      0       0    50  1300.0
# 3              11                Grajaú        2      1       0    70  1500.0
# 4              12   Lins de Vasconcelos        3      1       1    90  1500.0
# ...           ...                   ...      ...    ...     ...   ...     ...
# 18775       32951        Vila Valqueire        2      0       0    52  1000.0
# 18776       32953                 Méier        2      0       0    70   900.0
# 18777       32956           Jacarepaguá        3      1       2    78  1800.0
# 18778       32957  São Francisco Xavier        2      1       0    48  1400.0
# 18779       32958                Leblon        2      0       0    70  3000.0
#
#        Condominio  IPTU
# ...

# %%
df.to_csv('dados_apartamentos.csv', index=False)

# %%
pd.read_csv('dados_apartamentos.csv') # Veio sem o index novo
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2                  Cachambi        2      0       0    50  1300.0       301.0
# 3                    Grajaú        2      1       0    70  1500.0       642.0
# 4       Lins de Vasconcelos        3      1       1    90  1500.0       455.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 18775        Vila Valqueire        2      0       0    52  1000.0       550.0
# 18776                 Méier        2      0       0    70   900.0       490.0
# 18777           Jacarepaguá        3      1       2    78  1800.0       800.0
# 18778  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 18779                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %%
df.to_csv('dados_apartamentos.csv', index=False, sep=';')

# %%
pd.read_csv('dados_apartamentos.csv')
# Out:
#       Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0                       Centro;1;0;0;15;800.0;390.0;20.0
# 1                  Higienópolis;1;0;0;48;800.0;230.0;0.0
# 2                    Cachambi;2;0;0;50;1300.0;301.0;17.0
# 3                      Grajaú;2;1;0;70;1500.0;642.0;74.0
# 4         Lins de Vasconcelos;3;1;1;90;1500.0;455.0;14.0
# ...                                                  ...
# 18775           Vila Valqueire;2;0;0;52;1000.0;550.0;0.0
# 18776                    Méier;2;0;0;70;900.0;490.0;48.0
# 18777             Jacarepaguá;3;1;2;78;1800.0;800.0;40.0
# 18778    São Francisco Xavier;2;1;0;48;1400.0;509.0;37.0
# 18779                   Leblon;2;0;0;70;3000.0;760.0;0.0
#
# [18780 rows x 1 columns]

# %%
pd.read_csv('dados_apartamentos.csv', sep=';')
# Out:
#                      Bairro  Quartos  Vagas  Suites  Area   Valor  Condominio  \
# 0                    Centro        1      0       0    15   800.0       390.0
# 1              Higienópolis        1      0       0    48   800.0       230.0
# 2                  Cachambi        2      0       0    50  1300.0       301.0
# 3                    Grajaú        2      1       0    70  1500.0       642.0
# 4       Lins de Vasconcelos        3      1       1    90  1500.0       455.0
# ...                     ...      ...    ...     ...   ...     ...         ...
# 18775        Vila Valqueire        2      0       0    52  1000.0       550.0
# 18776                 Méier        2      0       0    70   900.0       490.0
# 18777           Jacarepaguá        3      1       2    78  1800.0       800.0
# 18778  São Francisco Xavier        2      1       0    48  1400.0       509.0
# 18779                Leblon        2      0       0    70  3000.0       760.0
#
#        IPTU
# 0      20.0
# ...

# %% [markdown]
# Com base nisso, salve esses DataFrames em 2 arquivos csv distintos para que o time de ML possa ter acesso a esses dados de forma mais prática.

# %%
df_1.to_csv('filtro_1.csv', index=False, sep=";")   # Salvando os filtros que fizemos em um arquivo csv separados por ;
df_2.to_csv('filtro_2.csv', index=False, sep=";")

# %% [markdown]
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.
#
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.
#
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.
#
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".
#
# Extra: Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. Dica: pesquise pelo método replace.

# %%
dados_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
dados_alunos.isnull().sum() # verificar se tem dados nulosvai coluna por culana ate achar os dados nulos
# Out:
# Nome        0
# Idade       0
# Notas       6
# Aprovado    0
# dtype: int64

# %%
dados_alunos = dados_alunos.fillna(0) # preencher os dados nulos com 0
dados_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
alunos_a_remover = dados_alunos.query('Nome == "Alice"| Nome == "Carlos"').index # # salvando os índices das linhas a serem removidas em uma variável

# %%
dados_alunos.drop(alunos_a_remover, axis=0, inplace=True) # removendo as linhas selecionadas

# %%
dados_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
selecao = dados_alunos['Aprovado'] == True

# %%
dados_alunos[selecao]
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %%
selecao_aprovados = dados_alunos[selecao]

# %%
selecao_aprovados.to_csv('alunos_aprovados.csv', index=False, sep=";")

# %%
selecao_aprovados.replace(7.0, 8.0)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %%
selecao_aprovados = selecao_aprovados.replace(7.0, 8.0)
selecao_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    8.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    8.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# # Manipulando os dados

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'  salvando o csv em uma variavel
dados = pd.read_csv(url, sep=';') # avisar que esta sendo separado por virgula

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
dados['Valor_por_mes'] = dados['Valor'] + dados['Condominio'] # vai somar os dois e criar uma nova
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes
# 0  1700.0       500.0    60.0         2200.0
# 1  7000.0         NaN     NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0
# 3   800.0       390.0    20.0         1190.0
# 4   800.0       230.0     NaN         1030.0

# %%
dados['Valor_por_ano'] = dados['Valor_por_mes'] * 12 + dados['IPTU'] # vai somar os dois e criar uma nova
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN

# %% [markdown]
# # Criando Colunas categoricas

# %%
dados['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] # estamos conctenando as duas infmraçoes na coluna nova que criamos par anosso dataframe
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                     Descricao
# 0                     Quitinete em Copacabana
# 1                     Casa em Jardim Botânico
# ...

# %%
dados['Descricao'] = dados['Tipo'] + ' em ' + dados['Bairro'] + ' com ' + \
                                        dados['Quartos'].astype(str) + ' quarto(s) ' + \
                                        ' e ' + dados['Vagas'].astype(str) + ' vaga(s) de garagem.'

                                        #Tive que transformar os dados int para string se não da erro
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao
# 0  Quitinete em Copacabana com 1 quarto(s)  e 0 v...
# ...

# %%
dados["Possui_suits"] = dados['Suites'].apply(lambda x: "Sim" if x > 0 else "Não") # usamos a função lambada se for x maior que zero sim se não for não

# %%
dados.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU  Valor_por_mes  Valor_por_ano  \
# 0  1700.0       500.0    60.0         2200.0        26460.0
# 1  7000.0         NaN     NaN            NaN            NaN
# 2  5200.0      4020.0  1111.0         9220.0       111751.0
# 3   800.0       390.0    20.0         1190.0        14300.0
# 4   800.0       230.0     NaN         1030.0            NaN
#
#                                            Descricao Possui_suits
# 0  Quitinete em Copacabana com 1 quarto(s)  e 0 v...          Não
# ...

# %%
dados.to_csv('dados_completos_dev.csv', index=False, sep=';') # salvando o arquivo

# %% [markdown]
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.
#
# 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.
#
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6).
# 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %%
dados_alunos['Pontos_extras'] = dados_alunos['Notas'].apply(lambda x: x*0.4) #  essa função lambada percorre todas as notas e faz x 0.4 para formar a coluna pontos extras
dados_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras
# 0         Ary     20    7.5      True            3.0
# 1         Ana     18    0.0     False            0.0
# 2       Cátia     27    2.5     False            1.0
# 3       Denis     18    5.0     False            2.0
# 4        Beto     21   10.0      True            4.0
# 5       Bruna     23    0.0     False            0.0
# 6        Dara     21    7.0      True            2.8
# 9       Vitor     28    0.0     False            0.0
# 10     Daniel     21    0.0     False            0.0
# 11       Igor     24    4.5     False            1.8
# 12  Sthefanie     26    9.5      True            3.8
# 13      Mirla     25    9.0      True            3.6
# 14      Paulo     37    0.0     False            0.0
# 15     Mylena     29    7.0      True            2.8
# 16      Lucas     33    0.0     False            0.0
# 17      Nadia     34    8.0      True            3.2

# %%
dados_alunos['Notas_finais'] = dados_alunos['Notas'] + dados_alunos['Pontos_extras']
dados_alunos   # somando as duas tabelas e criando uma nov a
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0         Ary     20    7.5      True            3.0          10.5
# 1         Ana     18    0.0     False            0.0           0.0
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 5       Bruna     23    0.0     False            0.0           0.0
# 6        Dara     21    7.0      True            2.8           9.8
# 9       Vitor     28    0.0     False            0.0           0.0
# 10     Daniel     21    0.0     False            0.0           0.0
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 14      Paulo     37    0.0     False            0.0           0.0
# ...

# %%
dados_alunos['Aprovado_final'] = dados_alunos['Notas_finais'].apply(lambda x: True if x >= 6 else False)
dados_alunos  # vai observar se é maior o menor que 6 e vim com resultado tru ou false
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20    7.5      True            3.0          10.5
# 1         Ana     18    0.0     False            0.0           0.0
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 5       Bruna     23    0.0     False            0.0           0.0
# 6        Dara     21    7.0      True            2.8           9.8
# 9       Vitor     28    0.0     False            0.0           0.0
# 10     Daniel     21    0.0     False            0.0           0.0
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 14      Paulo     37    0.0     False            0.0           0.0
# ...

# %%
dados_alunos.query('Aprovado == False & Aprovado_final == True')  # buscou usando o & as duas condicçoes tem que ser verdadeiras para vim
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  Aprovado_final
# 3   Denis     18    5.0     False            2.0           7.0            True
# 11   Igor     24    4.5     False            1.8           6.3            True

# %%
selecao = (dados_alunos['Aprovado'] == False) & (dados_alunos['Aprovado_final'] == True)
dados_alunos[selecao]
# Out:
#      Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  Aprovado_final
# 3   Denis     18    5.0     False            2.0           7.0            True
# 11   Igor     24    4.5     False            1.8           6.3            True
